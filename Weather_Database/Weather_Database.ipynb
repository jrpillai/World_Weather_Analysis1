# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 777

# %%
# for city in cities:
#     print(city)

# %%
# # Create a practice set of random latitude and longitude combinations.
# lats = [25.12903645, 25.92017388, 26.62509167, -59.98969384, 37.30571269]
# lngs = [-67.59741259, 11.09532135, 74.84233102, -76.89176677, -61.13376282]
# lat_lngs = zip(lats, lngs)

# %%
# # Add the latitudes and longitudes to a list.
# coordinates = list(lat_lngs)

# %%
# # Use the print() function to display the latitude and longitude combinations.
# for coordinate in coordinates:
#     print(coordinate[0], coordinate[1])

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather['weather'][0]['description']
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | gorontalo
# Processing Record 2 of Set 1 | lebu
# Processing Record 3 of Set 1 | aracoiaba
# Processing Record 4 of Set 1 | atuona
# Processing Record 5 of Set 1 | kuche
# City not found. Skipping...
# Processing Record 6 of Set 1 | ostrovnoy
# Processing Record 7 of Set 1 | hilo
# Processing Record 8 of Set 1 | bluff
# Processing Record 9 of Set 1 | rikitea
# Processing Record 10 of Set 1 | kaitangata
# Processing Record 11 of Set 1 | busselton
# Processing Record 12 of Set 1 | kruisfontein
# Processing Record 13 of Set 1 | ravar
# Processing Record 14 of Set 1 | saint-philippe
# Processing Record 15 of Set 1 | ushuaia
# Processing Record 16 of Set 1 | kapaa
# Processing Record 17 of Set 1 | iqaluit
# Processing Record 18 of Set 1 | punta arenas
# Processing Record 19 of Set 1 | tuktoyaktuk
# Processing Record 20 of Set 1 | punta alta
# Processing Record 21 of Set 1 | fernandina beach
# Processing Record 22 of Set 1 | talnakh
# Processing Record 23 of Set 1 | fort nelson
# Processing Record 24 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 25 of Set 1 | jamestown
# Processing Record 26 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 27 of Set 1 | tateyama
# Processing Record 28 of Set 1 | guajara-mirim
# City not found. Skipping...
# Processing Record 29 of Set 1 | severodvinsk
# Processing Record 30 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 31 of Set 1 | tawkar
# City not found. Skipping...
# Processing Record 32 of Set 1 | bud
# Processing Record 33 of Set 1 | vila velha
# Processing Record 34 of Set 1 | madimba
# Processing Record 35 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 36 of Set 1 | bosobolo
# Processing Record 37 of Set 1 | hobart
# Processing Record 38 of Set 1 | avarua
# Processing Record 39 of Set 1 | kita
# Processing Record 40 of Set 1 | aykhal
# Processing Record 41 of Set 1 | gazanjyk
# Processing Record 42 of Set 1 | port elizabeth
# Processing Record 43 of Set 1 | castro
# Processing Record 44 of Set 1 | butaritari
# Processing Record 45 of Set 1 | tasiilaq
# Processing Record 46 of Set 1 | chara
# Processing Record 47 of Set 1 | vardo
# Processing Record 48 of Set 1 | mar del plata
# Processing Record 49 of Set 1 | itupiranga
# Processing Record 50 of Set 1 | new norfolk
# Processing Record 1 of Set 2 | mataura
# Processing Record 2 of Set 2 | port-cartier
# Processing Record 3 of Set 2 | leningradskiy
# Processing Record 4 of Set 2 | wufeng
# Processing Record 5 of Set 2 | utiroa
# City not found. Skipping...
# Processing Record 6 of Set 2 | mercedes
# Processing Record 7 of Set 2 | high level
# Processing Record 8 of Set 2 | hermanus
# Processing Record 9 of Set 2 | longyearbyen
# Processing Record 10 of Set 2 | puerto ayora
# Processing Record 11 of Set 2 | nantucket
# Processing Record 12 of Set 2 | keila
# Processing Record 13 of Set 2 | barrow
# Processing Record 14 of Set 2 | broome
# Processing Record 15 of Set 2 | phalaborwa
# Processing Record 16 of Set 2 | bengkulu
# Processing Record 17 of Set 2 | comodoro rivadavia
# Processing Record 18 of Set 2 | stepnyak
# Processing Record 19 of Set 2 | puerto escondido
# Processing Record 20 of Set 2 | port alfred
# Processing Record 21 of Set 2 | hofn
# Processing Record 22 of Set 2 | ribeira grande
# Processing Record 23 of Set 2 | soyo
# Processing Record 24 of Set 2 | yining
# Processing Record 25 of Set 2 | adoni
# Processing Record 26 of Set 2 | wajir
# Processing Record 27 of Set 2 | henties bay
# Processing Record 28 of Set 2 | steamboat springs
# Processing Record 29 of Set 2 | yagodnoye
# Processing Record 30 of Set 2 | east london
# Processing Record 31 of Set 2 | muscat
# Processing Record 32 of Set 2 | san quintin
# Processing Record 33 of Set 2 | georgetown
# Processing Record 34 of Set 2 | kavieng
# Processing Record 35 of Set 2 | zhigansk
# Processing Record 36 of Set 2 | rolim de moura
# City not found. Skipping...
# Processing Record 37 of Set 2 | slave lake
# Processing Record 38 of Set 2 | itarema
# Processing Record 39 of Set 2 | cervo
# Processing Record 40 of Set 2 | cape town
# Processing Record 41 of Set 2 | bur gabo
# City not found. Skipping...
# Processing Record 42 of Set 2 | vaini
# Processing Record 43 of Set 2 | querfurt
# Processing Record 44 of Set 2 | choszczno
# Processing Record 45 of Set 2 | jiddah
# City not found. Skipping...
# Processing Record 46 of Set 2 | dingle
# Processing Record 47 of Set 2 | nome
# Processing Record 48 of Set 2 | mangan
# Processing Record 49 of Set 2 | esperance
# Processing Record 50 of Set 2 | norman wells
# Processing Record 1 of Set 3 | vestmanna
# Processing Record 2 of Set 3 | sao filipe
# Processing Record 3 of Set 3 | doka
# Processing Record 4 of Set 3 | torbay
# Processing Record 5 of Set 3 | mastic beach
# Processing Record 6 of Set 3 | paamiut
# Processing Record 7 of Set 3 | sola
# Processing Record 8 of Set 3 | port shepstone
# Processing Record 9 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 10 of Set 3 | kamenka
# Processing Record 11 of Set 3 | levski
# Processing Record 12 of Set 3 | tiksi
# Processing Record 13 of Set 3 | denizli
# Processing Record 14 of Set 3 | kavaratti
# Processing Record 15 of Set 3 | lavrentiya
# Processing Record 16 of Set 3 | burica
# City not found. Skipping...
# Processing Record 17 of Set 3 | beringovskiy
# Processing Record 18 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 19 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 20 of Set 3 | mursalimkino
# Processing Record 21 of Set 3 | narsaq
# Processing Record 22 of Set 3 | provideniya
# Processing Record 23 of Set 3 | kahului
# Processing Record 24 of Set 3 | mukhen
# Processing Record 25 of Set 3 | bosaso
# Processing Record 26 of Set 3 | tucurui
# Processing Record 27 of Set 3 | bokspits
# City not found. Skipping...
# Processing Record 28 of Set 3 | albany
# Processing Record 29 of Set 3 | aktau
# Processing Record 30 of Set 3 | okha
# Processing Record 31 of Set 3 | yellowknife
# Processing Record 32 of Set 3 | arraial do cabo
# Processing Record 33 of Set 3 | luis correia
# Processing Record 34 of Set 3 | lasa
# Processing Record 35 of Set 3 | dikson
# Processing Record 36 of Set 3 | qianguo
# Processing Record 37 of Set 3 | airai
# Processing Record 38 of Set 3 | acapulco
# Processing Record 39 of Set 3 | beisfjord
# Processing Record 40 of Set 3 | cruz
# Processing Record 41 of Set 3 | bethel
# Processing Record 42 of Set 3 | rafai
# Processing Record 43 of Set 3 | flinders
# Processing Record 44 of Set 3 | marsh harbour
# Processing Record 45 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 46 of Set 3 | tromso
# Processing Record 47 of Set 3 | mahebourg
# Processing Record 48 of Set 3 | korla
# Processing Record 49 of Set 3 | cururupu
# Processing Record 50 of Set 3 | mergui
# City not found. Skipping...
# Processing Record 1 of Set 4 | champasak
# Processing Record 2 of Set 4 | christchurch
# Processing Record 3 of Set 4 | saskylakh
# Processing Record 4 of Set 4 | ancud
# Processing Record 5 of Set 4 | nanortalik
# Processing Record 6 of Set 4 | college
# Processing Record 7 of Set 4 | tucuma
# Processing Record 8 of Set 4 | tocopilla
# Processing Record 9 of Set 4 | maningrida
# Processing Record 10 of Set 4 | chuy
# Processing Record 11 of Set 4 | nizwa
# Processing Record 12 of Set 4 | kuytun
# Processing Record 13 of Set 4 | saint george
# Processing Record 14 of Set 4 | asau
# Processing Record 15 of Set 4 | lompoc
# Processing Record 16 of Set 4 | karasjok
# Processing Record 17 of Set 4 | port blair
# Processing Record 18 of Set 4 | chokurdakh
# Processing Record 19 of Set 4 | katsuura
# Processing Record 20 of Set 4 | alotau
# City not found. Skipping...
# Processing Record 21 of Set 4 | padang
# Processing Record 22 of Set 4 | cairns
# Processing Record 23 of Set 4 | casablanca
# Processing Record 24 of Set 4 | chicama
# Processing Record 25 of Set 4 | khonuu
# City not found. Skipping...
# Processing Record 26 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 27 of Set 4 | qaanaaq
# Processing Record 28 of Set 4 | tura
# Processing Record 29 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 30 of Set 4 | upernavik
# Processing Record 31 of Set 4 | honiara
# Processing Record 32 of Set 4 | mackay
# Processing Record 33 of Set 4 | marawi
# Processing Record 34 of Set 4 | adamovka
# Processing Record 35 of Set 4 | mecca
# Processing Record 36 of Set 4 | yarada
# Processing Record 37 of Set 4 | cidreira
# Processing Record 38 of Set 4 | liverpool
# Processing Record 39 of Set 4 | gouyave
# Processing Record 40 of Set 4 | port hardy
# Processing Record 41 of Set 4 | eyemouth
# Processing Record 42 of Set 4 | nikolskoye
# Processing Record 43 of Set 4 | catamarca
# Processing Record 44 of Set 4 | kizukuri
# Processing Record 45 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 46 of Set 4 | ahipara
# Processing Record 47 of Set 4 | faya
# Processing Record 48 of Set 4 | iglino
# Processing Record 49 of Set 4 | leo
# Processing Record 50 of Set 4 | dawei
# Processing Record 1 of Set 5 | grand gaube
# Processing Record 2 of Set 5 | la ronge
# Processing Record 3 of Set 5 | coihaique
# Processing Record 4 of Set 5 | arlit
# Processing Record 5 of Set 5 | darnah
# Processing Record 6 of Set 5 | touros
# Processing Record 7 of Set 5 | pevek
# Processing Record 8 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 9 of Set 5 | tete
# Processing Record 10 of Set 5 | camargo
# Processing Record 11 of Set 5 | khovu-aksy
# Processing Record 12 of Set 5 | codrington
# Processing Record 13 of Set 5 | siilinjarvi
# Processing Record 14 of Set 5 | karratha
# Processing Record 15 of Set 5 | wittlich
# Processing Record 16 of Set 5 | caconda
# Processing Record 17 of Set 5 | hithadhoo
# Processing Record 18 of Set 5 | stornoway
# Processing Record 19 of Set 5 | praia da vitoria
# Processing Record 20 of Set 5 | vao
# Processing Record 21 of Set 5 | perth
# Processing Record 22 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 23 of Set 5 | houma
# Processing Record 24 of Set 5 | valparaiso
# Processing Record 25 of Set 5 | tsabong
# Processing Record 26 of Set 5 | aklavik
# Processing Record 27 of Set 5 | bredasdorp
# Processing Record 28 of Set 5 | rayadrug
# Processing Record 29 of Set 5 | hervey bay
# Processing Record 30 of Set 5 | terra santa
# Processing Record 31 of Set 5 | kalevala
# Processing Record 32 of Set 5 | auki
# Processing Record 33 of Set 5 | nanga eboko
# Processing Record 34 of Set 5 | huarmey
# Processing Record 35 of Set 5 | olafsvik
# Processing Record 36 of Set 5 | severo-kurilsk
# Processing Record 37 of Set 5 | turka
# Processing Record 38 of Set 5 | kirkuk
# Processing Record 39 of Set 5 | taltal
# Processing Record 40 of Set 5 | waingapu
# Processing Record 41 of Set 5 | bossembele
# City not found. Skipping...
# Processing Record 42 of Set 5 | prince rupert
# Processing Record 43 of Set 5 | leshukonskoye
# Processing Record 44 of Set 5 | aksu
# Processing Record 45 of Set 5 | pinsk
# Processing Record 46 of Set 5 | linjiang
# Processing Record 47 of Set 5 | mahon
# Processing Record 48 of Set 5 | pyu
# Processing Record 49 of Set 5 | byron bay
# Processing Record 50 of Set 5 | bubaque
# Processing Record 1 of Set 6 | avera
# Processing Record 2 of Set 6 | guerrero negro
# Processing Record 3 of Set 6 | morrope
# Processing Record 4 of Set 6 | santa marta
# Processing Record 5 of Set 6 | khatanga
# Processing Record 6 of Set 6 | antonio escobedo
# Processing Record 7 of Set 6 | halalo
# City not found. Skipping...
# Processing Record 8 of Set 6 | merrill
# Processing Record 9 of Set 6 | monte alegre
# Processing Record 10 of Set 6 | feijo
# Processing Record 11 of Set 6 | yirol
# City not found. Skipping...
# Processing Record 12 of Set 6 | clyde river
# Processing Record 13 of Set 6 | karaul
# City not found. Skipping...
# Processing Record 14 of Set 6 | rivadavia
# Processing Record 15 of Set 6 | tommot
# Processing Record 16 of Set 6 | jackson
# Processing Record 17 of Set 6 | lorengau
# Processing Record 18 of Set 6 | ponta do sol
# Processing Record 19 of Set 6 | whitehorse
# Processing Record 20 of Set 6 | wuwei
# Processing Record 21 of Set 6 | grand centre
# City not found. Skipping...
# Processing Record 22 of Set 6 | vuktyl
# Processing Record 23 of Set 6 | bacarra
# Processing Record 24 of Set 6 | linxia
# Processing Record 25 of Set 6 | komsomolskiy
# Processing Record 26 of Set 6 | hovd
# Processing Record 27 of Set 6 | lagoa
# Processing Record 28 of Set 6 | miandrivazo
# Processing Record 29 of Set 6 | hvittingfoss
# Processing Record 30 of Set 6 | yamada
# Processing Record 31 of Set 6 | saldanha
# Processing Record 32 of Set 6 | nguiu
# City not found. Skipping...
# Processing Record 33 of Set 6 | tongzi
# Processing Record 34 of Set 6 | bad frankenhausen
# Processing Record 35 of Set 6 | tuatapere
# Processing Record 36 of Set 6 | vestmannaeyjar
# Processing Record 37 of Set 6 | sorland
# Processing Record 38 of Set 6 | jacareacanga
# Processing Record 39 of Set 6 | candido mendes
# Processing Record 40 of Set 6 | kodiak
# Processing Record 41 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 42 of Set 6 | ambalavao
# Processing Record 43 of Set 6 | opuwo
# Processing Record 44 of Set 6 | piacabucu
# Processing Record 45 of Set 6 | geraldton
# Processing Record 46 of Set 6 | turayf
# Processing Record 47 of Set 6 | wroclaw
# Processing Record 48 of Set 6 | tidore
# City not found. Skipping...
# Processing Record 49 of Set 6 | warmbad
# Processing Record 50 of Set 6 | antalaha
# Processing Record 1 of Set 7 | leonidion
# City not found. Skipping...
# Processing Record 2 of Set 7 | botwood
# Processing Record 3 of Set 7 | mushie
# Processing Record 4 of Set 7 | back mountain
# Processing Record 5 of Set 7 | puerto del rosario
# Processing Record 6 of Set 7 | ilulissat
# Processing Record 7 of Set 7 | rudnogorsk
# Processing Record 8 of Set 7 | pangnirtung
# Processing Record 9 of Set 7 | prokopyevsk
# Processing Record 10 of Set 7 | thompson
# Processing Record 11 of Set 7 | lardos
# Processing Record 12 of Set 7 | la romana
# Processing Record 13 of Set 7 | victoria
# Processing Record 14 of Set 7 | russell
# Processing Record 15 of Set 7 | flin flon
# Processing Record 16 of Set 7 | constantine
# Processing Record 17 of Set 7 | palmer
# Processing Record 18 of Set 7 | sitka
# Processing Record 19 of Set 7 | tamandare
# Processing Record 20 of Set 7 | webuye
# Processing Record 21 of Set 7 | bac can
# City not found. Skipping...
# Processing Record 22 of Set 7 | gafanha da encarnacao
# Processing Record 23 of Set 7 | ghanzi
# Processing Record 24 of Set 7 | sinnamary
# Processing Record 25 of Set 7 | sulangan
# Processing Record 26 of Set 7 | piney green
# Processing Record 27 of Set 7 | matagami
# Processing Record 28 of Set 7 | cherskiy
# Processing Record 29 of Set 7 | ulaanbaatar
# Processing Record 30 of Set 7 | namatanai
# Processing Record 31 of Set 7 | hualmay
# Processing Record 32 of Set 7 | sri aman
# Processing Record 33 of Set 7 | veraval
# Processing Record 34 of Set 7 | okhotsk
# Processing Record 35 of Set 7 | kovdor
# Processing Record 36 of Set 7 | axim
# Processing Record 37 of Set 7 | rocha
# Processing Record 38 of Set 7 | coahuayana
# Processing Record 39 of Set 7 | pingliang
# Processing Record 40 of Set 7 | talara
# Processing Record 41 of Set 7 | ukiah
# Processing Record 42 of Set 7 | sohag
# Processing Record 43 of Set 7 | nouadhibou
# Processing Record 44 of Set 7 | arkalgud
# Processing Record 45 of Set 7 | westerland
# Processing Record 46 of Set 7 | brae
# Processing Record 47 of Set 7 | bacolod
# Processing Record 48 of Set 7 | inhapim
# Processing Record 49 of Set 7 | santa luzia
# Processing Record 50 of Set 7 | hvolsvollur
# Processing Record 1 of Set 8 | yulara
# Processing Record 2 of Set 8 | lucapa
# Processing Record 3 of Set 8 | villamontes
# Processing Record 4 of Set 8 | matay
# Processing Record 5 of Set 8 | agadez
# Processing Record 6 of Set 8 | pyshma
# Processing Record 7 of Set 8 | ostersund
# Processing Record 8 of Set 8 | constitucion
# Processing Record 9 of Set 8 | itapirapua
# Processing Record 10 of Set 8 | fortuna
# Processing Record 11 of Set 8 | san cristobal
# Processing Record 12 of Set 8 | bafoulabe
# Processing Record 13 of Set 8 | diffa
# Processing Record 14 of Set 8 | lewistown
# Processing Record 15 of Set 8 | freeport
# Processing Record 16 of Set 8 | wagga wagga
# Processing Record 17 of Set 8 | tual
# Processing Record 18 of Set 8 | lydenburg
# Processing Record 19 of Set 8 | massaguet
# Processing Record 20 of Set 8 | kenosha
# Processing Record 21 of Set 8 | taybad
# Processing Record 22 of Set 8 | novopavlovka
# Processing Record 23 of Set 8 | alofi
# Processing Record 24 of Set 8 | ixtapa
# Processing Record 25 of Set 8 | merauke
# Processing Record 26 of Set 8 | san patricio
# Processing Record 27 of Set 8 | rorvik
# Processing Record 28 of Set 8 | abu samrah
# Processing Record 29 of Set 8 | nishihara
# Processing Record 30 of Set 8 | sokoni
# Processing Record 31 of Set 8 | narsingi
# Processing Record 32 of Set 8 | vanavara
# Processing Record 33 of Set 8 | makakilo city
# Processing Record 34 of Set 8 | karamay
# City not found. Skipping...
# Processing Record 35 of Set 8 | kalmunai
# Processing Record 36 of Set 8 | xinzhi
# Processing Record 37 of Set 8 | batken
# Processing Record 38 of Set 8 | carnarvon
# Processing Record 39 of Set 8 | kampot
# Processing Record 40 of Set 8 | dong hoi
# Processing Record 41 of Set 8 | derzhavinsk
# Processing Record 42 of Set 8 | ajdabiya
# Processing Record 43 of Set 8 | bambanglipuro
# Processing Record 44 of Set 8 | pundaguitan
# Processing Record 45 of Set 8 | road town
# Processing Record 46 of Set 8 | louisbourg
# City not found. Skipping...
# Processing Record 47 of Set 8 | hobyo
# Processing Record 48 of Set 8 | gizo
# Processing Record 49 of Set 8 | berezovyy
# Processing Record 50 of Set 8 | izumo
# Processing Record 1 of Set 9 | ures
# Processing Record 2 of Set 9 | haines junction
# Processing Record 3 of Set 9 | tonota
# Processing Record 4 of Set 9 | cockburn town
# Processing Record 5 of Set 9 | laguna
# Processing Record 6 of Set 9 | roald
# Processing Record 7 of Set 9 | aflu
# City not found. Skipping...
# Processing Record 8 of Set 9 | lamu
# Processing Record 9 of Set 9 | sorvag
# City not found. Skipping...
# Processing Record 10 of Set 9 | maryville
# Processing Record 11 of Set 9 | san ignacio
# Processing Record 12 of Set 9 | viedma
# Processing Record 13 of Set 9 | skibbereen
# Processing Record 14 of Set 9 | de aar
# Processing Record 15 of Set 9 | candeias
# Processing Record 16 of Set 9 | rio grande
# Processing Record 17 of Set 9 | aswan
# Processing Record 18 of Set 9 | sisimiut
# Processing Record 19 of Set 9 | hamilton
# Processing Record 20 of Set 9 | batticaloa
# Processing Record 21 of Set 9 | rabo de peixe
# Processing Record 22 of Set 9 | trojes
# Processing Record 23 of Set 9 | woodstock
# Processing Record 24 of Set 9 | chabahar
# Processing Record 25 of Set 9 | lumberton
# Processing Record 26 of Set 9 | nemuro
# Processing Record 27 of Set 9 | khlung
# Processing Record 28 of Set 9 | saint anthony
# Processing Record 29 of Set 9 | todos santos
# Processing Record 30 of Set 9 | roma
# Processing Record 31 of Set 9 | sillamae
# Processing Record 32 of Set 9 | goya
# Processing Record 33 of Set 9 | plastun
# Processing Record 34 of Set 9 | fare
# Processing Record 35 of Set 9 | pochutla
# Processing Record 36 of Set 9 | nioro
# Processing Record 37 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 38 of Set 9 | kieta
# Processing Record 39 of Set 9 | goroka
# Processing Record 40 of Set 9 | tessalit
# Processing Record 41 of Set 9 | platanos
# Processing Record 42 of Set 9 | pacific grove
# Processing Record 43 of Set 9 | gali
# Processing Record 44 of Set 9 | hay river
# Processing Record 45 of Set 9 | jingdezhen
# Processing Record 46 of Set 9 | tingrela
# City not found. Skipping...
# Processing Record 47 of Set 9 | vilhena
# Processing Record 48 of Set 9 | gelemso
# Processing Record 49 of Set 9 | soe
# Processing Record 50 of Set 9 | kitzingen
# Processing Record 1 of Set 10 | port keats
# Processing Record 2 of Set 10 | skalistyy
# City not found. Skipping...
# Processing Record 3 of Set 10 | pokrovsk-uralskiy
# City not found. Skipping...
# Processing Record 4 of Set 10 | zanjan
# Processing Record 5 of Set 10 | hasaki
# Processing Record 6 of Set 10 | moranbah
# Processing Record 7 of Set 10 | okakarara
# Processing Record 8 of Set 10 | pavlovsk
# Processing Record 9 of Set 10 | libreville
# Processing Record 10 of Set 10 | antsohihy
# Processing Record 11 of Set 10 | conceicao do araguaia
# Processing Record 12 of Set 10 | labrea
# Processing Record 13 of Set 10 | aurangabad
# Processing Record 14 of Set 10 | sept-iles
# Processing Record 15 of Set 10 | sibolga
# Processing Record 16 of Set 10 | hudiksvall
# Processing Record 17 of Set 10 | hami
# Processing Record 18 of Set 10 | biskamzha
# Processing Record 19 of Set 10 | kuna
# Processing Record 20 of Set 10 | yinchuan
# Processing Record 21 of Set 10 | port macquarie
# Processing Record 22 of Set 10 | cuiluan
# Processing Record 23 of Set 10 | oxbow
# Processing Record 24 of Set 10 | paciran
# Processing Record 25 of Set 10 | rovenki
# Processing Record 26 of Set 10 | kapit
# Processing Record 27 of Set 10 | maloarkhangelsk
# Processing Record 28 of Set 10 | boa vista
# Processing Record 29 of Set 10 | arroyo
# Processing Record 30 of Set 10 | caravelas
# Processing Record 31 of Set 10 | calvinia
# Processing Record 32 of Set 10 | qaqortoq
# Processing Record 33 of Set 10 | mount darwin
# Processing Record 34 of Set 10 | kathmandu
# Processing Record 35 of Set 10 | broken hill
# Processing Record 36 of Set 10 | inongo
# Processing Record 37 of Set 10 | luneville
# Processing Record 38 of Set 10 | isangel
# Processing Record 39 of Set 10 | takoradi
# Processing Record 40 of Set 10 | praia
# Processing Record 41 of Set 10 | kitimat
# Processing Record 42 of Set 10 | tagusao
# Processing Record 43 of Set 10 | praya
# Processing Record 44 of Set 10 | kichera
# Processing Record 45 of Set 10 | sol-iletsk
# Processing Record 46 of Set 10 | togur
# Processing Record 47 of Set 10 | noumea
# Processing Record 48 of Set 10 | turukhansk
# Processing Record 49 of Set 10 | cabo san lucas
# Processing Record 50 of Set 10 | goma
# Processing Record 1 of Set 11 | alice springs
# Processing Record 2 of Set 11 | monte patria
# Processing Record 3 of Set 11 | singaraja
# Processing Record 4 of Set 11 | port hedland
# Processing Record 5 of Set 11 | bodden town
# Processing Record 6 of Set 11 | west fargo
# Processing Record 7 of Set 11 | sapa
# Processing Record 8 of Set 11 | harper
# Processing Record 9 of Set 11 | pisco
# Processing Record 10 of Set 11 | mlonggo
# Processing Record 11 of Set 11 | husavik
# Processing Record 12 of Set 11 | onega
# Processing Record 13 of Set 11 | the valley
# Processing Record 14 of Set 11 | marzuq
# Processing Record 15 of Set 11 | gambela
# Processing Record 16 of Set 11 | fallon
# Processing Record 17 of Set 11 | kloulklubed
# Processing Record 18 of Set 11 | vysokogornyy
# Processing Record 19 of Set 11 | orange
# Processing Record 20 of Set 11 | erenhot
# Processing Record 21 of Set 11 | oussouye
# Processing Record 22 of Set 11 | lysva
# Processing Record 23 of Set 11 | channel-port aux basques
# Processing Record 24 of Set 11 | artyk
# City not found. Skipping...
# Processing Record 25 of Set 11 | kenora
# Processing Record 26 of Set 11 | beloha
# Processing Record 27 of Set 11 | wum
# Processing Record 28 of Set 11 | baykit
# Processing Record 29 of Set 11 | asosa
# Processing Record 30 of Set 11 | buin
# Processing Record 31 of Set 11 | mahanoro
# Processing Record 32 of Set 11 | shelburne
# Processing Record 33 of Set 11 | at-bashi
# Processing Record 34 of Set 11 | luderitz
# Processing Record 35 of Set 11 | samusu
# City not found. Skipping...
# Processing Record 36 of Set 11 | seoul
# Processing Record 37 of Set 11 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 38 of Set 11 | aloleng
# Processing Record 39 of Set 11 | havre-saint-pierre
# Processing Record 40 of Set 11 | japura
# Processing Record 41 of Set 11 | eregli
# Processing Record 42 of Set 11 | zhanatas
# City not found. Skipping...
# Processing Record 43 of Set 11 | ahar
# Processing Record 44 of Set 11 | jieshi
# Processing Record 45 of Set 11 | shingu
# Processing Record 46 of Set 11 | howard springs
# Processing Record 47 of Set 11 | berlevag
# Processing Record 48 of Set 11 | conceicao da barra
# Processing Record 49 of Set 11 | bilibino
# Processing Record 50 of Set 11 | malumfashi
# Processing Record 1 of Set 12 | datong
# Processing Record 2 of Set 12 | klaksvik
# Processing Record 3 of Set 12 | gat
# Processing Record 4 of Set 12 | kiruna
# Processing Record 5 of Set 12 | abapo
# Processing Record 6 of Set 12 | ruatoria
# City not found. Skipping...
# Processing Record 7 of Set 12 | bandarbeyla
# Processing Record 8 of Set 12 | alta
# Processing Record 9 of Set 12 | tomatlan
# Processing Record 10 of Set 12 | zhuozhou
# City not found. Skipping...
# Processing Record 11 of Set 12 | eyl
# Processing Record 12 of Set 12 | kushiro
# Processing Record 13 of Set 12 | vale da amoreira
# Processing Record 14 of Set 12 | lensk
# Processing Record 15 of Set 12 | sao miguel do araguaia
# Processing Record 16 of Set 12 | harboore
# Processing Record 17 of Set 12 | raca
# Processing Record 18 of Set 12 | dolbeau
# City not found. Skipping...
# Processing Record 19 of Set 12 | saint-pierre
# Processing Record 20 of Set 12 | mahina
# Processing Record 21 of Set 12 | moron
# Processing Record 22 of Set 12 | sarangani
# Processing Record 23 of Set 12 | alyangula
# Processing Record 24 of Set 12 | kot addu
# Processing Record 25 of Set 12 | storforshei
# Processing Record 26 of Set 12 | garoua
# Processing Record 27 of Set 12 | dudinka
# Processing Record 28 of Set 12 | lazaro cardenas
# Processing Record 29 of Set 12 | sechura
# Processing Record 30 of Set 12 | mehamn
# Processing Record 31 of Set 12 | orillia
# Processing Record 32 of Set 12 | erzin
# Processing Record 33 of Set 12 | omsukchan
# Processing Record 34 of Set 12 | tiverton
# Processing Record 35 of Set 12 | vostok
# Processing Record 36 of Set 12 | tarija
# Processing Record 37 of Set 12 | evensk
# Processing Record 38 of Set 12 | westport
# Processing Record 39 of Set 12 | clyde
# Processing Record 40 of Set 12 | hirara
# Processing Record 41 of Set 12 | morgan city
# Processing Record 42 of Set 12 | satitoa
# City not found. Skipping...
# Processing Record 43 of Set 12 | tabas
# Processing Record 44 of Set 12 | tabiauea
# City not found. Skipping...
# Processing Record 45 of Set 12 | melekhovskaya
# City not found. Skipping...
# Processing Record 46 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 47 of Set 12 | fairbanks
# Processing Record 48 of Set 12 | northam
# Processing Record 49 of Set 12 | longview
# Processing Record 50 of Set 12 | ekibastuz
# Processing Record 1 of Set 13 | lerwick
# Processing Record 2 of Set 13 | mana
# Processing Record 3 of Set 13 | amambai
# Processing Record 4 of Set 13 | kourou
# Processing Record 5 of Set 13 | yuancheng
# Processing Record 6 of Set 13 | chapleau
# Processing Record 7 of Set 13 | castelo do piaui
# Processing Record 8 of Set 13 | jaora
# Processing Record 9 of Set 13 | marsa matruh
# Processing Record 10 of Set 13 | la libertad
# Processing Record 11 of Set 13 | yerbogachen
# Processing Record 12 of Set 13 | namtsy
# Processing Record 13 of Set 13 | lieksa
# Processing Record 14 of Set 13 | am timan
# Processing Record 15 of Set 13 | coquimbo
# Processing Record 16 of Set 13 | carutapera
# Processing Record 17 of Set 13 | shu
# Processing Record 18 of Set 13 | bandundu
# Processing Record 19 of Set 13 | kyren
# Processing Record 20 of Set 13 | asfi
# Processing Record 21 of Set 13 | pecos
# Processing Record 22 of Set 13 | vershino-darasunskiy
# Processing Record 23 of Set 13 | tazovskiy
# Processing Record 24 of Set 13 | muisne
# Processing Record 25 of Set 13 | ouadda
# Processing Record 26 of Set 13 | miraflores
# Processing Record 27 of Set 13 | berdigestyakh
# Processing Record 28 of Set 13 | dunedin
# Processing Record 29 of Set 13 | clovis
# Processing Record 30 of Set 13 | horuphav
# Processing Record 31 of Set 13 | del rio
# Processing Record 32 of Set 13 | rincon
# Processing Record 33 of Set 13 | balsas
# Processing Record 34 of Set 13 | gazli
# Processing Record 35 of Set 13 | coos bay
# Processing Record 36 of Set 13 | atar
# Processing Record 37 of Set 13 | mineros
# Processing Record 38 of Set 13 | campoverde
# Processing Record 39 of Set 13 | taoudenni
# Processing Record 40 of Set 13 | tambun
# Processing Record 41 of Set 13 | nador
# Processing Record 42 of Set 13 | saint-joseph
# Processing Record 43 of Set 13 | rawson
# Processing Record 44 of Set 13 | xingyi
# Processing Record 45 of Set 13 | elliot lake
# Processing Record 46 of Set 13 | ilebo
# Processing Record 47 of Set 13 | tiarei
# Processing Record 48 of Set 13 | shubarkuduk
# Processing Record 49 of Set 13 | finschhafen
# Processing Record 50 of Set 13 | ullapool
# Processing Record 1 of Set 14 | nkoteng
# Processing Record 2 of Set 14 | manokwari
# Processing Record 3 of Set 14 | cayenne
# Processing Record 4 of Set 14 | tanete
# Processing Record 5 of Set 14 | belle glade
# Processing Record 6 of Set 14 | homer
# Processing Record 7 of Set 14 | kolyvan
# Processing Record 8 of Set 14 | batemans bay
# Processing Record 9 of Set 14 | saint-francois
# Processing Record 10 of Set 14 | pacifica
# Processing Record 11 of Set 14 | inirida
# Processing Record 12 of Set 14 | udachnyy
# Processing Record 13 of Set 14 | dargaville
# Processing Record 14 of Set 14 | palu
# Processing Record 15 of Set 14 | north platte
# Processing Record 16 of Set 14 | lata
# Processing Record 17 of Set 14 | aksarka
# Processing Record 18 of Set 14 | borovoy
# Processing Record 19 of Set 14 | mitu
# Processing Record 20 of Set 14 | sioux lookout
# Processing Record 21 of Set 14 | anshun
# Processing Record 22 of Set 14 | duminichi
# Processing Record 23 of Set 14 | nieuwpoort
# Processing Record 24 of Set 14 | seymchan
# Processing Record 25 of Set 14 | samarai
# Processing Record 26 of Set 14 | srednekolymsk
# Processing Record 27 of Set 14 | edgewater
# Processing Record 28 of Set 14 | sao joao da barra
# Processing Record 29 of Set 14 | jinchang
# Processing Record 30 of Set 14 | bathsheba
# Processing Record 31 of Set 14 | zhenlai
# Processing Record 32 of Set 14 | barcelos
# Processing Record 33 of Set 14 | willowmore
# Processing Record 34 of Set 14 | galiakot
# Processing Record 35 of Set 14 | burla
# Processing Record 36 of Set 14 | yumen
# Processing Record 37 of Set 14 | pokaran
# Processing Record 38 of Set 14 | kamenskoye
# City not found. Skipping...
# Processing Record 39 of Set 14 | teguldet
# Processing Record 40 of Set 14 | coxim
# Processing Record 41 of Set 14 | araguaina
# Processing Record 42 of Set 14 | camacha
# Processing Record 43 of Set 14 | ust-nera
# Processing Record 44 of Set 14 | cap malheureux
# Processing Record 45 of Set 14 | genhe
# Processing Record 46 of Set 14 | matara
# Processing Record 47 of Set 14 | pingzhuang
# Processing Record 48 of Set 14 | morondava
# Processing Record 49 of Set 14 | warqla
# City not found. Skipping...
# Processing Record 50 of Set 14 | mahibadhoo
# Processing Record 1 of Set 15 | myitkyina
# Processing Record 2 of Set 15 | chapais
# Processing Record 3 of Set 15 | port antonio
# Processing Record 4 of Set 15 | faanui
# Processing Record 5 of Set 15 | tautira
# Processing Record 6 of Set 15 | acu
# Processing Record 7 of Set 15 | kanodar
# Processing Record 8 of Set 15 | umm kaddadah
# Processing Record 9 of Set 15 | deputatskiy
# Processing Record 10 of Set 15 | celestun
# Processing Record 11 of Set 15 | mayna
# Processing Record 12 of Set 15 | arman
# Processing Record 13 of Set 15 | bukama
# Processing Record 14 of Set 15 | galiwinku
# City not found. Skipping...
# Processing Record 15 of Set 15 | zarichne
# Processing Record 16 of Set 15 | van buren
# Processing Record 17 of Set 15 | daura
# Processing Record 18 of Set 15 | ngunguru
# Processing Record 19 of Set 15 | ivanava
# Processing Record 20 of Set 15 | champerico
# Processing Record 21 of Set 15 | wilmington
# Processing Record 22 of Set 15 | halifax
# Processing Record 23 of Set 15 | meulaboh
# Processing Record 24 of Set 15 | maragogi
# Processing Record 25 of Set 15 | iberia
# Processing Record 26 of Set 15 | alta floresta
# Processing Record 27 of Set 15 | puerto quijarro
# Processing Record 28 of Set 15 | portland
# Processing Record 29 of Set 15 | swan hill
# Processing Record 30 of Set 15 | gubkinskiy
# Processing Record 31 of Set 15 | sosnovo-ozerskoye
# Processing Record 32 of Set 15 | lunen
# Processing Record 33 of Set 15 | klichka
# Processing Record 34 of Set 15 | gigmoto
# Processing Record 35 of Set 15 | mandiana
# Processing Record 36 of Set 15 | marfino
# Processing Record 37 of Set 15 | saint-augustin
# Processing Record 38 of Set 15 | krasnoselkup
# Processing Record 39 of Set 15 | susanino
# Processing Record 40 of Set 15 | verkh-usugli
# Processing Record 41 of Set 15 | santa vitoria do palmar
# Processing Record 42 of Set 15 | petapa
# Processing Record 43 of Set 15 | poltavka
# Processing Record 44 of Set 15 | xining
# Processing Record 45 of Set 15 | sistranda
# Processing Record 46 of Set 15 | paytug
# City not found. Skipping...
# Processing Record 47 of Set 15 | pampierstad
# Processing Record 48 of Set 15 | kyaikto
# Processing Record 49 of Set 15 | mandalgovi
# Processing Record 50 of Set 15 | port lincoln
# Processing Record 1 of Set 16 | alappuzha
# Processing Record 2 of Set 16 | los llanos de aridane
# Processing Record 3 of Set 16 | jalu
# Processing Record 4 of Set 16 | puerto leguizamo
# Processing Record 5 of Set 16 | palabuhanratu
# City not found. Skipping...
# Processing Record 6 of Set 16 | khandyga
# Processing Record 7 of Set 16 | davidson
# Processing Record 8 of Set 16 | manzil kamil
# Processing Record 9 of Set 16 | grojec
# Processing Record 10 of Set 16 | namibe
# Processing Record 11 of Set 16 | souillac
# Processing Record 12 of Set 16 | trelew
# Processing Record 13 of Set 16 | weligama
# Processing Record 14 of Set 16 | banjar
# Processing Record 15 of Set 16 | x-can
# City not found. Skipping...
# Processing Record 16 of Set 16 | bocas del toro
# Processing Record 17 of Set 16 | volta redonda
# Processing Record 18 of Set 16 | mitsamiouli
# Processing Record 19 of Set 16 | tiznit
# Processing Record 20 of Set 16 | methoni
# Processing Record 21 of Set 16 | kurumkan
# Processing Record 22 of Set 16 | sayyan
# Processing Record 23 of Set 16 | sao felix do xingu
# Processing Record 24 of Set 16 | simbahan
# Processing Record 25 of Set 16 | huron
# Processing Record 26 of Set 16 | tapejara
# Processing Record 27 of Set 16 | kaoma
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#         City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Gorontalo      ID   0.5412  123.0595     74.17        96         100
# 1       Lebu      CL -37.6167  -73.6500     51.62        85          57
# 2  Aracoiaba      BR  -4.3711  -38.8142     81.55        69          97
# 3     Atuona      PF  -9.8000 -139.0333     77.94        77          18
# 4  Ostrovnoy      RU  68.0531   39.5131     58.84        73          13
#
#    Wind Speed Current Description
# 0        2.06          light rain
# 1       16.42       broken clouds
# 2        4.38     overcast clouds
# 3       21.30          few clouds
# 4       10.27          few clouds

# %%
# # Rename "Description" to "Current Description" to match module
# city_data_df = city_data_df.rename({'Description' : 'Current Description'}, axis=1)
# city_data_df.head()

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
